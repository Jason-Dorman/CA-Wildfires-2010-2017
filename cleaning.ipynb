# %%
import pdftables_api

# %%
c = pdftables_api.Client('jj1btnkhsrxk')
c.csv('2016_FiresByCause.pdf', '2016_FiresByCause.csv')

# %%
a = pdftables_api.Client('jj1btnkhsrxk')
a.csv('2015_Fires_SouthernRegion.pdf', '2015_fires_southern.csv')

# %%
b = pdftables_api.Client('jj1btnkhsrxk')
b.csv('2015_Fires_NorthernRegion.pdf', '2015_fires_northern.csv')

# %%
d = pdftables_api.Client('jj1btnkhsrxk')
d.csv('2014_FiresbyCauseSouth.pdf', '2014_fires_south.csv')

# %%
e = pdftables_api.Client('jj1btnkhsrxk')
e.csv('2014_FiresbyCauseNorth.pdf', '2014_fires_north.csv')

# %%
f = pdftables_api.Client('jj1btnkhsrxk')
f.csv('FiresByCause_2013_southern.pdf', '2013_fires_south.csv')

# %%
g = pdftables_api.Client('jj1btnkhsrxk')
g.csv('FiresByCause_Northern_2013.pdf', '2013_fires_north.csv')

# %%
h = pdftables_api.Client('jj1btnkhsrxk')
h.csv('2012_Fires_byCause_Northern.pdf', '2012_fires_north.csv')

# %%
i = pdftables_api.Client('jj1btnkhsrxk')
i.csv('2012_Fires_byCause_Southern.pdf', '2012_fires_sout.csv')

# %%
j = pdftables_api.Client('jj1btnkhsrxk')
j.csv('2011_Fires_byCause_Northern.pdf', '2011_fires_north.csv')

# %%
k = pdftables_api.Client('jj1btnkhsrxk')
k.csv('2011_Fires_byCause_Southern.pdf', '2011_fires_south.csv')

# %%
l = pdftables_api.Client('jj1btnkhsrxk')
l.csv('2010_FiresCause_NorthernRegion.pdf', '2010_fires_north.csv')

# %%
m = pdftables_api.Client('jj1btnkhsrxk')
m.csv('2010_FiresCause_SouthernRegion.pdf', '2010_fires_south.csv')

# %%
import pandas as pd

# %%
f2016 = pd.read_csv("2016_FiresByCause.csv")

f2016.head()
# Out:
#       COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0    Alameda     39      0         0                0             8
# 1     Alpine      0      0         0                0             0
# 2     Amador     57      2         0               17             6
# 3      Butte      0      0         0                0             0
# 4  Calaveras     94      1         3               22             9
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0            4      0      4      0         0        0      16        7  2016
# 1            0      0      0      0         0        0       0        0  2016
# 2            7      1      7      0         0        3       5        9  2016
# 3            0      0      0      0         0        0       0        0  2016
# 4           14      0     12      2         0        1      21        9  2016

# %%
f2015_south = pd.read_csv('2015_fires_southern.csv')

f2015_south.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0    Fresno    115     35         3                8            12
# 1     Kings      2      0         0                0             0
# 2    Madera     74      7         2               17             7
# 3  Mariposa     44      4         2               20             0
# 4    Merced     19      4         0                0             1
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0           10     20      7      0         0        1      12        7  2015
# 1            0      0      0      0         0        0       2        0  2015
# 2            7      1      4      4         0        0      16        9  2015
# 3            5      1      5      0         0        1       4        2  2015
# 4            0      1      2      0         0        0       5        6  2015

# %%
f2015_north = pd.read_csv('2015_fires_northern.csv')

f2015_north.head()
# Out:
#         COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0       Amador     46      2         1               14             5
# 1    El Dorado    205      9         4               50            17
# 2   Sacramento     16      1         0                1             2
# 3  San Joaquin      6      0         0                0             1
# 4        Butte     11      0         1                0             0
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0            1      4      5      0         0        1       9        4  2015
# 1           19     12     35      5         0        4      38       12  2015
# 2            1      0      3      1         0        0       4        3  2015
# 3            1      0      1      0         0        0       2        1  2015
# 4            0      3      5      0         0        0       1        1  2015

# %%
f2015 = pd.concat([f2015_north, f2015_south])

f2015.head()
# Out:
#         COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0       Amador     46      2         1               14             5
# 1    El Dorado    205      9         4               50            17
# 2   Sacramento     16      1         0                1             2
# 3  San Joaquin      6      0         0                0             1
# 4        Butte     11      0         1                0             0
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0            1      4      5      0         0        1       9        4  2015
# 1           19     12     35      5         0        4      38       12  2015
# 2            1      0      3      1         0        0       4        3  2015
# 3            1      0      1      0         0        0       2        1  2015
# 4            0      3      5      0         0        0       1        1  2015

# %%
f2015 = f2015.reset_index()

f2015.head()
# Out:
#    index       COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0      0       Amador     46      2         1               14             5
# 1      1    El Dorado    205      9         4               50            17
# 2      2   Sacramento     16      1         0                1             2
# 3      3  San Joaquin      6      0         0                0             1
# 4      4        Butte     11      0         1                0             0
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0            1      4      5      0         0        1       9        4  2015
# 1           19     12     35      5         0        4      38       12  2015
# 2            1      0      3      1         0        0       4        3  2015
# 3            1      0      1      0         0        0       2        1  2015
# 4            0      3      5      0         0        0       1        1  2015

# %%
f2015 = f2015.drop('index', axis=1)

# %%
f2015.head()
# Out:
#         COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0       Amador     46      2         1               14             5
# 1    El Dorado    205      9         4               50            17
# 2   Sacramento     16      1         0                1             2
# 3  San Joaquin      6      0         0                0             1
# 4        Butte     11      0         1                0             0
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0            1      4      5      0         0        1       9        4  2015
# 1           19     12     35      5         0        4      38       12  2015
# 2            1      0      3      1         0        0       4        3  2015
# 3            1      0      1      0         0        0       2        1  2015
# 4            0      3      5      0         0        0       1        1  2015

# %%
fires_merged = pd.concat([f2016, f2015])

fires_merged.head()
# Out:
#       COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0    Alameda     39      0         0                0             8
# 1     Alpine      0      0         0                0             0
# 2     Amador     57      2         0               17             6
# 3      Butte      0      0         0                0             0
# 4  Calaveras     94      1         3               22             9
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0            4      0      4      0         0        0      16        7  2016
# 1            0      0      0      0         0        0       0        0  2016
# 2            7      1      7      0         0        3       5        9  2016
# 3            0      0      0      0         0        0       0        0  2016
# 4           14      0     12      2         0        1      21        9  2016

# %%
f2014_south = pd.read_csv('2014_fires_south.csv')

f2014_south.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0    Fresno     57      5         2               12             5
# 1     Kings      3      0         0                0             0
# 2    Madera     72     12         4                9             2
# 3  Mariposa     38      1         2               12             5
# 4    Merced     14      0         0                0             2
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0            4      1      9      0         0        1      13        5  2014
# 1            0      0      1      0         0        0       0        2  2014
# 2            3      2     12      1         0        1      19        7  2014
# 3            1      1      1      0         0        1      12        2  2014
# 4            0      0      1      0         0        0      10        1  2014

# %%
f2014_north = pd.read_csv('2014_fires_north.csv')

f2014_north.head()
# Out:
#         COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0       Amador     67      2         3               14             6
# 1    El Dorado    174      3         3               41            11
# 2   Sacramento     15      1         0                1             2
# 3  San Joaquin      6      0         0                0             0
# 4        Butte    192     40         2               34            11
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0           12      1     15      1         0        0       9        4  2014
# 1           18      9     32      5         0        4      26       22  2014
# 2            2      0      2      0         0        0       5        2  2014
# 3            2      0      0      0         0        0       3        1  2014
# 4            9      4     47      6         0        2      22       15  2014

# %%
f2014 = pd.concat([f2014_south, f2014_north])

f2014.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0    Fresno     57      5         2               12             5
# 1     Kings      3      0         0                0             0
# 2    Madera     72     12         4                9             2
# 3  Mariposa     38      1         2               12             5
# 4    Merced     14      0         0                0             2
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0            4      1      9      0         0        1      13        5  2014
# 1            0      0      1      0         0        0       0        2  2014
# 2            3      2     12      1         0        1      19        7  2014
# 3            1      1      1      0         0        1      12        2  2014
# 4            0      0      1      0         0        0      10        1  2014

# %%
f2014 = f2014.reset_index()

f2014.head()
# Out:
#    index    COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0      0    Fresno     57      5         2               12             5
# 1      1     Kings      3      0         0                0             0
# 2      2    Madera     72     12         4                9             2
# 3      3  Mariposa     38      1         2               12             5
# 4      4    Merced     14      0         0                0             2
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0            4      1      9      0         0        1      13        5  2014
# 1            0      0      1      0         0        0       0        2  2014
# 2            3      2     12      1         0        1      19        7  2014
# 3            1      1      1      0         0        1      12        2  2014
# 4            0      0      1      0         0        0      10        1  2014

# %%
f2014 = f2014.drop('index', axis=1)

# %%
f2014.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0    Fresno     57      5         2               12             5
# 1     Kings      3      0         0                0             0
# 2    Madera     72     12         4                9             2
# 3  Mariposa     38      1         2               12             5
# 4    Merced     14      0         0                0             2
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0            4      1      9      0         0        1      13        5  2014
# 1            0      0      1      0         0        0       0        2  2014
# 2            3      2     12      1         0        1      19        7  2014
# 3            1      1      1      0         0        1      12        2  2014
# 4            0      0      1      0         0        0      10        1  2014

# %%
fires_merged = pd.concat([fires_merged, f2014])

fires_merged.head()
# Out:
#       COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0    Alameda     39      0         0                0             8
# 1     Alpine      0      0         0                0             0
# 2     Amador     57      2         0               17             6
# 3      Butte      0      0         0                0             0
# 4  Calaveras     94      1         3               22             9
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0            4      0      4      0         0        0      16        7  2016
# 1            0      0      0      0         0        0       0        0  2016
# 2            7      1      7      0         0        3       5        9  2016
# 3            0      0      0      0         0        0       0        0  2016
# 4           14      0     12      2         0        1      21        9  2016

# %%
f2013_south = pd.read_csv('2013_fires_south.csv')

f2013_south.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0    Fresno     64      3         0                8            12
# 1     Kings      4      0         0                0             1
# 2    Madera    102     13         6                7             5
# 3  Mariposa     38      0         1                7             2
# 4    Merced     20      1         0                1             4
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0           10      5      5      2         0        0      15        4  2013
# 1            0      0      0      0         0        0       1        2  2013
# 2            7      3      5      2         0        2      40       12  2013
# 3            3      0      5      0         0        4      13        3  2013
# 4            1      0      0      0         0        3      10        0  2013

# %%
f2013_north = pd.read_csv('2013_fires_north.csv')

f2013_north.head()
# Out:
#   NORTHERN REGION  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0          Amador     64      5         0               20             7
# 1       El Dorado    236      5         5               66            18
# 2      Sacramento     17      1         0                1             3
# 3     San Joaquin      8      1         0                1             0
# 4           Butte    210     13         6               39            15
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle
# 0            5      0     14      1         0        0      10        2
# 1           24      4     63      8         0        4      18       21
# 2            4      0      0      0         0        0       6        2
# 3            2      0      0      0         0        0       3        1
# 4            9     15     50      8         0        2      42       11

# %%
f2013_north = f2013_north.rename(columns={'NORTHERN REGION': 'COUNTY'})

f2013_north.head()
# Out:
#         COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0       Amador     64      5         0               20             7
# 1    El Dorado    236      5         5               66            18
# 2   Sacramento     17      1         0                1             3
# 3  San Joaquin      8      1         0                1             0
# 4        Butte    210     13         6               39            15
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle
# 0            5      0     14      1         0        0      10        2
# 1           24      4     63      8         0        4      18       21
# 2            4      0      0      0         0        0       6        2
# 3            2      0      0      0         0        0       3        1
# 4            9     15     50      8         0        2      42       11

# %%
f2013_north['Year'] = '2013'

f2013_north.head()
# Out:
#         COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0       Amador     64      5         0               20             7
# 1    El Dorado    236      5         5               66            18
# 2   Sacramento     17      1         0                1             3
# 3  San Joaquin      8      1         0                1             0
# 4        Butte    210     13         6               39            15
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0            5      0     14      1         0        0      10        2  2013
# 1           24      4     63      8         0        4      18       21  2013
# 2            4      0      0      0         0        0       6        2  2013
# 3            2      0      0      0         0        0       3        1  2013
# 4            9     15     50      8         0        2      42       11  2013

# %%
f2013 = pd.concat([f2013_south, f2013_north])

f2013.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0    Fresno     64      3         0                8            12
# 1     Kings      4      0         0                0             1
# 2    Madera    102     13         6                7             5
# 3  Mariposa     38      0         1                7             2
# 4    Merced     20      1         0                1             4
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0           10      5      5      2         0        0      15        4  2013
# 1            0      0      0      0         0        0       1        2  2013
# 2            7      3      5      2         0        2      40       12  2013
# 3            3      0      5      0         0        4      13        3  2013
# 4            1      0      0      0         0        3      10        0  2013

# %%
f2013 = f2013.reset_index()

f2013.head()
# Out:
#    index    COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0      0    Fresno     64      3         0                8            12
# 1      1     Kings      4      0         0                0             1
# 2      2    Madera    102     13         6                7             5
# 3      3  Mariposa     38      0         1                7             2
# 4      4    Merced     20      1         0                1             4
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0           10      5      5      2         0        0      15        4  2013
# 1            0      0      0      0         0        0       1        2  2013
# 2            7      3      5      2         0        2      40       12  2013
# 3            3      0      5      0         0        4      13        3  2013
# 4            1      0      0      0         0        3      10        0  2013

# %%
f2013 = f2013.drop('index', axis=1)

# %%
f2013.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0    Fresno     64      3         0                8            12
# 1     Kings      4      0         0                0             1
# 2    Madera    102     13         6                7             5
# 3  Mariposa     38      0         1                7             2
# 4    Merced     20      1         0                1             4
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0           10      5      5      2         0        0      15        4  2013
# 1            0      0      0      0         0        0       1        2  2013
# 2            7      3      5      2         0        2      40       12  2013
# 3            3      0      5      0         0        4      13        3  2013
# 4            1      0      0      0         0        3      10        0  2013

# %%
fires_merged = pd.concat([fires_merged, f2013])

fires_merged.head()
# Out:
#       COUNTY  Total  Arson  Campfire  Debris\nBurning  Elec.\nPower  \
# 0    Alameda     39      0         0                0             8
# 1     Alpine      0      0         0                0             0
# 2     Amador     57      2         0               17             6
# 3      Butte      0      0         0                0             0
# 4  Calaveras     94      1         3               22             9
#
#    Equip.\nUse  Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0            4      0      4      0         0        0      16        7  2016
# 1            0      0      0      0         0        0       0        0  2016
# 2            7      1      7      0         0        3       5        9  2016
# 3            0      0      0      0         0        0       0        0  2016
# 4           14      0     12      2         0        1      21        9  2016

# %%
f2012_south = pd.read_csv('2012_fires_south.csv')

f2012_south.head()
# Out:
#   SOUTHERN REGION  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  \
# 0          Fresno     95     10         1               6          14      3
# 1           Kings      6      0         0               0           0      1
# 2          Madera     72      6         3              13           1      0
# 3        Mariposa     48      2         1              18           5      0
# 4          Merced     15      0         0               0           0      1
#
#    Misc.  Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle
# 0     13         18      0         0        1      19       10
# 1      1          1      0         0        0       3        0
# 2     11          4      1         0        1      25        7
# 3      5          4      1         0        1       6        5
# 4      2          1      0         0        0       9        2

# %%
f2012_south = f2012_south.rename(columns={'SOUTHERN REGION': 'COUNTY'})

f2012_south['Year'] = '2012'

f2012_south.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  Misc.  \
# 0    Fresno     95     10         1               6          14      3     13
# 1     Kings      6      0         0               0           0      1      1
# 2    Madera     72      6         3              13           1      0     11
# 3  Mariposa     48      2         1              18           5      0      5
# 4    Merced     15      0         0               0           0      1      2
#
#    Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0         18      0         0        1      19       10  2012
# 1          1      0         0        0       3        0  2012
# 2          4      1         0        1      25        7  2012
# 3          4      1         0        1       6        5  2012
# 4          1      0         0        0       9        2  2012

# %%
f2012_north = pd.read_csv('2012_fires_north.csv')

f2012_north.head()
# Out:
#   NORTHERN REGION  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  \
# 0          Amador     55      1         2              17           6      8
# 1       El Dorado    169      6         1              41          18     17
# 2      Sacramento     12      0         0               0           3      0
# 3           Butte    114      6         0              15          13      0
# 4          Tehama      4      1         0               0           1      0
#
#    Misc.  Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle
# 0     11          3      0         0        0       5        2
# 1     32         13      3         0        7      20       11
# 2      2          0      0         0        1       6        0
# 3     19          4      7         0        2      29       19
# 4      0          0      0         0        0       2        0

# %%
f2012_north = f2012_north.rename(columns={'NORTHERN REGION': 'COUNTY'})

f2012_north['Year'] = '2012'

f2012_north.head()
# Out:
#        COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  \
# 0      Amador     55      1         2              17           6      8
# 1   El Dorado    169      6         1              41          18     17
# 2  Sacramento     12      0         0               0           3      0
# 3       Butte    114      6         0              15          13      0
# 4      Tehama      4      1         0               0           1      0
#
#    Misc.  Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0     11          3      0         0        0       5        2  2012
# 1     32         13      3         0        7      20       11  2012
# 2      2          0      0         0        1       6        0  2012
# 3     19          4      7         0        2      29       19  2012
# 4      0          0      0         0        0       2        0  2012

# %%
f2012 = pd.concat([f2012_south, f2012_north])

f2012.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  Misc.  \
# 0    Fresno     95     10         1               6          14      3     13
# 1     Kings      6      0         0               0           0      1      1
# 2    Madera     72      6         3              13           1      0     11
# 3  Mariposa     48      2         1              18           5      0      5
# 4    Merced     15      0         0               0           0      1      2
#
#    Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0         18      0         0        1      19       10  2012
# 1          1      0         0        0       3        0  2012
# 2          4      1         0        1      25        7  2012
# 3          4      1         0        1       6        5  2012
# 4          1      0         0        0       9        2  2012

# %%
f2012 = f2012.reset_index()

f2012.head()
# Out:
#    index    COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  \
# 0      0    Fresno     95     10         1               6          14      3
# 1      1     Kings      6      0         0               0           0      1
# 2      2    Madera     72      6         3              13           1      0
# 3      3  Mariposa     48      2         1              18           5      0
# 4      4    Merced     15      0         0               0           0      1
#
#    Misc.  Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0     13         18      0         0        1      19       10  2012
# 1      1          1      0         0        0       3        0  2012
# 2     11          4      1         0        1      25        7  2012
# 3      5          4      1         0        1       6        5  2012
# 4      2          1      0         0        0       9        2  2012

# %%
f2012 = f2012.drop('index', axis=1)

# %%
f2012.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  Misc.  \
# 0    Fresno     95     10         1               6          14      3     13
# 1     Kings      6      0         0               0           0      1      1
# 2    Madera     72      6         3              13           1      0     11
# 3  Mariposa     48      2         1              18           5      0      5
# 4    Merced     15      0         0               0           0      1      2
#
#    Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0         18      0         0        1      19       10  2012
# 1          1      0         0        0       3        0  2012
# 2          4      1         0        1      25        7  2012
# 3          4      1         0        1       6        5  2012
# 4          1      0         0        0       9        2  2012

# %%
f2011_south = pd.read_csv('2011_fires_south.csv')

f2011_south.head()
# Out:
#   SOUTHERN REGION  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  \
# 0          Fresno    110      5         1              13          24      2
# 1           Kings      5      0         0               0           2      0
# 2          Madera     73      2         1              14           7      1
# 3        Mariposa     49      1         0              10           6      1
# 4          Merced     23      0         0               0           2      0
#
#    Misc.  Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle
# 0     38         11      0         0        0      14        2
# 1      2          0      0         0        0       1        0
# 2     16          3      1         0        0      27        1
# 3     18          1      0         0        0      12        0
# 4      8          2      0         0        0      10        1

# %%
f2011_south = f2011_south.rename(columns={'SOUTHERN REGION': 'COUNTY'})

f2011_south['Year'] = '2011'

f2011_south.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  Misc.  \
# 0    Fresno    110      5         1              13          24      2     38
# 1     Kings      5      0         0               0           2      0      2
# 2    Madera     73      2         1              14           7      1     16
# 3  Mariposa     49      1         0              10           6      1     18
# 4    Merced     23      0         0               0           2      0      8
#
#    Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0         11      0         0        0      14        2  2011
# 1          0      0         0        0       1        0  2011
# 2          3      1         0        0      27        1  2011
# 3          1      0         0        0      12        0  2011
# 4          2      0         0        0      10        1  2011

# %%
f2011_north = pd.read_csv('2011_fires_north.csv')

f2011_north.head()
# Out:
#   NORTHERN\nREGION  Total  Arson  Campfire  Debris\nBurning  Equip.\nUse  \
# 0           Amador     51      1         0               10            6
# 1        El Dorado    143      2         0               42           18
# 2       Sacramento     15      2         0                0            2
# 3      San Joaquin      7      0         0                0            1
# 4            Butte    164     24         1               29           16
#
#    Ltng.  Misc.  Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle
# 0      0     21          2      0         0        0       8        3
# 1      2     53          7      0         0        1      14        4
# 2      0      7          1      0         0        0       3        0
# 3      0      4          0      0         0        0       2        0
# 4      2     48          9      0         0        2      27        6

# %%
f2011_north.columns
# Out:
# Index(['NORTHERN\nREGION', 'Total', 'Arson', 'Campfire', 'Debris\nBurning',
#        'Equip.\nUse', 'Ltng.', 'Misc.', 'Powerline', 'P-W-F', 'Railroad',
#        'Smoking', 'Undet.', 'Vehicle'],
#       dtype='object')

# %%
f2011_south.columns
# Out:
# Index(['COUNTY', 'Total', 'Arson', 'Campfire', 'Debris Burning', 'Equip. Use',
#        'Ltng.', 'Misc.', 'Powerline', 'P-W-F', 'Railroad', 'Smoking', 'Undet.',
#        'Vehicle', 'Year'],
#       dtype='object')

# %%
fires_merged.columns
# Out:
# Index(['COUNTY', 'Total', 'Arson', 'Campfire', 'Debris\nBurning',
#        'Elec.\nPower', 'Equip.\nUse', 'Ltng.', 'Misc.', 'P-W-F', 'Railroad',
#        'Smoking', 'Undet.', 'Vehicle', 'Year'],
#       dtype='object')

# %%
f2012.columns
# Out:
# Index(['COUNTY', 'Total', 'Arson', 'Campfire', 'Debris Burning', 'Equip. Use',
#        'Ltng.', 'Misc.', 'Powerline', 'P-W-F', 'Railroad', 'Smoking', 'Undet.',
#        'Vehicle', 'Year'],
#       dtype='object')

# %%
f2011_north = f2011_north.rename(columns={'NORTHERN\nREGION': 'COUNTY'})

f2011_north['Year'] = '2011'

f2011_north.head()
# Out:
#         COUNTY  Total  Arson  Campfire  Debris\nBurning  Equip.\nUse  Ltng.  \
# 0       Amador     51      1         0               10            6      0
# 1    El Dorado    143      2         0               42           18      2
# 2   Sacramento     15      2         0                0            2      0
# 3  San Joaquin      7      0         0                0            1      0
# 4        Butte    164     24         1               29           16      2
#
#    Misc.  Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0     21          2      0         0        0       8        3  2011
# 1     53          7      0         0        1      14        4  2011
# 2      7          1      0         0        0       3        0  2011
# 3      4          0      0         0        0       2        0  2011
# 4     48          9      0         0        2      27        6  2011

# %%
f2011_north = f2011_north.rename(columns={'Debris\nBurning': 'Debris Burning', 'Equip.\nUse': 'Equip. Use',})

# %%
f2011 = pd.concat([f2011_north, f2011_south])

f2011.head()
# Out:
#         COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  \
# 0       Amador     51      1         0              10           6      0
# 1    El Dorado    143      2         0              42          18      2
# 2   Sacramento     15      2         0               0           2      0
# 3  San Joaquin      7      0         0               0           1      0
# 4        Butte    164     24         1              29          16      2
#
#    Misc.  Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0     21          2      0         0        0       8        3  2011
# 1     53          7      0         0        1      14        4  2011
# 2      7          1      0         0        0       3        0  2011
# 3      4          0      0         0        0       2        0  2011
# 4     48          9      0         0        2      27        6  2011

# %%
f2011 = f2011.reset_index()

f2011.head()
# Out:
#    index       COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  \
# 0      0       Amador     51      1         0              10           6
# 1      1    El Dorado    143      2         0              42          18
# 2      2   Sacramento     15      2         0               0           2
# 3      3  San Joaquin      7      0         0               0           1
# 4      4        Butte    164     24         1              29          16
#
#    Ltng.  Misc.  Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0      0     21          2      0         0        0       8        3  2011
# 1      2     53          7      0         0        1      14        4  2011
# 2      0      7          1      0         0        0       3        0  2011
# 3      0      4          0      0         0        0       2        0  2011
# 4      2     48          9      0         0        2      27        6  2011

# %%
f2011 = f2011.drop('index', axis=1)

# %%
f2011.head()
# Out:
#         COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  \
# 0       Amador     51      1         0              10           6      0
# 1    El Dorado    143      2         0              42          18      2
# 2   Sacramento     15      2         0               0           2      0
# 3  San Joaquin      7      0         0               0           1      0
# 4        Butte    164     24         1              29          16      2
#
#    Misc.  Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0     21          2      0         0        0       8        3  2011
# 1     53          7      0         0        1      14        4  2011
# 2      7          1      0         0        0       3        0  2011
# 3      4          0      0         0        0       2        0  2011
# 4     48          9      0         0        2      27        6  2011

# %%
fires_merged_2 = pd.concat([f2012, f2011])

fires_merged_2.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  Misc.  \
# 0    Fresno     95     10         1               6          14      3     13
# 1     Kings      6      0         0               0           0      1      1
# 2    Madera     72      6         3              13           1      0     11
# 3  Mariposa     48      2         1              18           5      0      5
# 4    Merced     15      0         0               0           0      1      2
#
#    Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0         18      0         0        1      19       10  2012
# 1          1      0         0        0       3        0  2012
# 2          4      1         0        1      25        7  2012
# 3          4      1         0        1       6        5  2012
# 4          1      0         0        0       9        2  2012

# %%
f2010_south = pd.read_csv('2010_fires_south.csv')

f2010_south.head()
# Out:
#   SOUTHERN REGION  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  \
# 0          Fresno     51      2         0               5           7      0
# 1           Kings      1      0         0               0           0      0
# 2          Madera     48      0         0               4           3      2
# 3        Mariposa     31      0         0               4           8      0
# 4          Merced     28      1         0               1           4      0
#
#    Misc.  P-W-F  Powerline  Railroad  Smoking  Undet.  Vehicle
# 0     10      0          6         0        1      19        1
# 1      0      0          0         0        0       1        0
# 2     17      0          0         0        0      21        1
# 3     10      0          2         0        0       6        1
# 4      3      0          3         0        1      14        1

# %%
f2010_south = f2010_south.rename(columns={'SOUTHERN REGION': 'COUNTY'})

f2010_south['Year'] = '2010'

f2010_south.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  Misc.  \
# 0    Fresno     51      2         0               5           7      0     10
# 1     Kings      1      0         0               0           0      0      0
# 2    Madera     48      0         0               4           3      2     17
# 3  Mariposa     31      0         0               4           8      0     10
# 4    Merced     28      1         0               1           4      0      3
#
#    P-W-F  Powerline  Railroad  Smoking  Undet.  Vehicle  Year
# 0      0          6         0        1      19        1  2010
# 1      0          0         0        0       1        0  2010
# 2      0          0         0        0      21        1  2010
# 3      0          2         0        0       6        1  2010
# 4      0          3         0        1      14        1  2010

# %%
f2010_north = pd.read_csv('2010_fires_north.csv')

f2010_north.head()
# Out:
#   NORTHERN\nREGION  Total  Arson  Campfire  Debris\nBurning  Equip.\nUse  \
# 0           Amador     41      0         0               15            4
# 1        El Dorado    109      5         0               36            7
# 2       Sacramento     23      4         0                1            3
# 3      San Joaquin     10      0         0                1            1
# 4            Butte     85      8         1               13           14
#
#    Ltng.  Misc.  P-W-F  Powerline  Railroad  Smoking  Undet.  Vehicle
# 0      0     19      0          2         0        0       1        0
# 1      0     37      0          3         0        3      17        1
# 2      0      5      0          6         0        0       4        0
# 3      0      5      0          0         0        0       3        0
# 4      0     24      0          3         0        2      18        1

# %%
f2010_north.columns
# Out:
# Index(['NORTHERN\nREGION', 'Total', 'Arson', 'Campfire', 'Debris\nBurning',
#        'Equip.\nUse', 'Ltng.', 'Misc.', 'P-W-F', 'Powerline', 'Railroad',
#        'Smoking', 'Undet.', 'Vehicle'],
#       dtype='object')

# %%
f2010_south.columns
# Out:
# Index(['COUNTY', 'Total', 'Arson', 'Campfire', 'Debris Burning', 'Equip. Use',
#        'Ltng.', 'Misc.', 'P-W-F', 'Powerline', 'Railroad', 'Smoking', 'Undet.',
#        'Vehicle', 'Year'],
#       dtype='object')

# %%
f2010_north = f2010_north.rename(columns={'NORTHERN\nREGION': 'COUNTY', 'Debris\nBurning': 'Debris Burning', 'Equip.\nUse':  'Equip. Use'})

f2010_north['Year'] = '2010'

f2010_north.head()
# Out:
#         COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  \
# 0       Amador     41      0         0              15           4      0
# 1    El Dorado    109      5         0              36           7      0
# 2   Sacramento     23      4         0               1           3      0
# 3  San Joaquin     10      0         0               1           1      0
# 4        Butte     85      8         1              13          14      0
#
#    Misc.  P-W-F  Powerline  Railroad  Smoking  Undet.  Vehicle  Year
# 0     19      0          2         0        0       1        0  2010
# 1     37      0          3         0        3      17        1  2010
# 2      5      0          6         0        0       4        0  2010
# 3      5      0          0         0        0       3        0  2010
# 4     24      0          3         0        2      18        1  2010

# %%
f2010 = pd.concat([f2010_north, f2010_south])

f2010.head()
# Out:
#         COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  \
# 0       Amador     41      0         0              15           4      0
# 1    El Dorado    109      5         0              36           7      0
# 2   Sacramento     23      4         0               1           3      0
# 3  San Joaquin     10      0         0               1           1      0
# 4        Butte     85      8         1              13          14      0
#
#    Misc.  P-W-F  Powerline  Railroad  Smoking  Undet.  Vehicle  Year
# 0     19      0          2         0        0       1        0  2010
# 1     37      0          3         0        3      17        1  2010
# 2      5      0          6         0        0       4        0  2010
# 3      5      0          0         0        0       3        0  2010
# 4     24      0          3         0        2      18        1  2010

# %%
f2010 = f2010.reset_index()

f2010.head()
# Out:
#    index       COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  \
# 0      0       Amador     41      0         0              15           4
# 1      1    El Dorado    109      5         0              36           7
# 2      2   Sacramento     23      4         0               1           3
# 3      3  San Joaquin     10      0         0               1           1
# 4      4        Butte     85      8         1              13          14
#
#    Ltng.  Misc.  P-W-F  Powerline  Railroad  Smoking  Undet.  Vehicle  Year
# 0      0     19      0          2         0        0       1        0  2010
# 1      0     37      0          3         0        3      17        1  2010
# 2      0      5      0          6         0        0       4        0  2010
# 3      0      5      0          0         0        0       3        0  2010
# 4      0     24      0          3         0        2      18        1  2010

# %%
f2010 = f2010.drop('index', axis=1)

# %%
f2010.head()
# Out:
#         COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  \
# 0       Amador     41      0         0              15           4      0
# 1    El Dorado    109      5         0              36           7      0
# 2   Sacramento     23      4         0               1           3      0
# 3  San Joaquin     10      0         0               1           1      0
# 4        Butte     85      8         1              13          14      0
#
#    Misc.  P-W-F  Powerline  Railroad  Smoking  Undet.  Vehicle  Year
# 0     19      0          2         0        0       1        0  2010
# 1     37      0          3         0        3      17        1  2010
# 2      5      0          6         0        0       4        0  2010
# 3      5      0          0         0        0       3        0  2010
# 4     24      0          3         0        2      18        1  2010

# %%
f2010.columns
# Out:
# Index(['COUNTY', 'Total', 'Arson', 'Campfire', 'Debris Burning', 'Equip. Use',
#        'Ltng.', 'Misc.', 'P-W-F', 'Powerline', 'Railroad', 'Smoking', 'Undet.',
#        'Vehicle', 'Year'],
#       dtype='object')

# %%
fires_merged_2.columns
# Out:
# Index(['COUNTY', 'Total', 'Arson', 'Campfire', 'Debris Burning', 'Equip. Use',
#        'Ltng.', 'Misc.', 'Powerline', 'P-W-F', 'Railroad', 'Smoking', 'Undet.',
#        'Vehicle', 'Year'],
#       dtype='object')

# %%
f2010 = f2010[['COUNTY', 'Total', 'Arson', 'Campfire', 'Debris Burning', 'Equip. Use',
       'Ltng.', 'Misc.', 'Powerline', 'P-W-F', 'Railroad', 'Smoking', 'Undet.',
       'Vehicle', 'Year']]

f2010.head()
# Out:
#         COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  \
# 0       Amador     41      0         0              15           4      0
# 1    El Dorado    109      5         0              36           7      0
# 2   Sacramento     23      4         0               1           3      0
# 3  San Joaquin     10      0         0               1           1      0
# 4        Butte     85      8         1              13          14      0
#
#    Misc.  Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0     19          2      0         0        0       1        0  2010
# 1     37          3      0         0        3      17        1  2010
# 2      5          6      0         0        0       4        0  2010
# 3      5          0      0         0        0       3        0  2010
# 4     24          3      0         0        2      18        1  2010

# %%
fires_merged_2 = pd.concat([fires_merged_2, f2010])

fires_merged_2.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris Burning  Equip. Use  Ltng.  Misc.  \
# 0    Fresno     95     10         1               6          14      3     13
# 1     Kings      6      0         0               0           0      1      1
# 2    Madera     72      6         3              13           1      0     11
# 3  Mariposa     48      2         1              18           5      0      5
# 4    Merced     15      0         0               0           0      1      2
#
#    Powerline  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0         18      0         0        1      19       10  2012
# 1          1      0         0        0       3        0  2012
# 2          4      1         0        1      25        7  2012
# 3          4      1         0        1       6        5  2012
# 4          1      0         0        0       9        2  2012

# %%
fires_merged_2.columns
# Out:
# Index(['COUNTY', 'Total', 'Arson', 'Campfire', 'Debris Burning', 'Equip. Use',
#        'Ltng.', 'Misc.', 'Powerline', 'P-W-F', 'Railroad', 'Smoking', 'Undet.',
#        'Vehicle', 'Year'],
#       dtype='object')

# %%
fires_merged.columns
# Out:
# Index(['COUNTY', 'Total', 'Arson', 'Campfire', 'Debris\nBurning',
#        'Elec.\nPower', 'Equip.\nUse', 'Ltng.', 'Misc.', 'P-W-F', 'Railroad',
#        'Smoking', 'Undet.', 'Vehicle', 'Year'],
#       dtype='object')

# %%
fires_merged_2 = fires_merged_2.rename(columns={'Powerline': 'Elec. Power'})

fires_merged_2.columns
# Out:
# Index(['COUNTY', 'Total', 'Arson', 'Campfire', 'Debris Burning', 'Equip. Use',
#        'Ltng.', 'Misc.', 'Elec. Power', 'P-W-F', 'Railroad', 'Smoking',
#        'Undet.', 'Vehicle', 'Year'],
#       dtype='object')

# %%
fires_merged = fires_merged.rename(columns={'Debris\nBurning': 'Debris Burning', 'Elec.\nPower': 'Elec. Power', 'Equip.\nUse': 'Equip. Use'})

fires_merged.columns
# Out:
# Index(['COUNTY', 'Total', 'Arson', 'Campfire', 'Debris Burning', 'Elec. Power',
#        'Equip. Use', 'Ltng.', 'Misc.', 'P-W-F', 'Railroad', 'Smoking',
#        'Undet.', 'Vehicle', 'Year'],
#       dtype='object')

# %%
fires_merged_2 = fires_merged_2[['COUNTY', 'Total', 'Arson', 'Campfire', 'Debris Burning', 'Elec. Power',
       'Equip. Use', 'Ltng.', 'Misc.', 'P-W-F', 'Railroad', 'Smoking',
       'Undet.', 'Vehicle', 'Year']]

fires_merged_2.head()
# Out:
#      COUNTY  Total  Arson  Campfire  Debris Burning  Elec. Power  Equip. Use  \
# 0    Fresno     95     10         1               6           18          14
# 1     Kings      6      0         0               0            1           0
# 2    Madera     72      6         3              13            4           1
# 3  Mariposa     48      2         1              18            4           5
# 4    Merced     15      0         0               0            1           0
#
#    Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0      3     13      0         0        1      19       10  2012
# 1      1      1      0         0        0       3        0  2012
# 2      0     11      1         0        1      25        7  2012
# 3      0      5      1         0        1       6        5  2012
# 4      1      2      0         0        0       9        2  2012

# %%
all_fires = pd.concat([fires_merged, fires_merged_2])

all_fires.head()
# Out:
#       COUNTY  Total  Arson  Campfire  Debris Burning  Elec. Power  Equip. Use  \
# 0    Alameda     39      0         0               0            8           4
# 1     Alpine      0      0         0               0            0           0
# 2     Amador     57      2         0              17            6           7
# 3      Butte      0      0         0               0            0           0
# 4  Calaveras     94      1         3              22            9          14
#
#    Ltng.  Misc.  P-W-F  Railroad  Smoking  Undet.  Vehicle  Year
# 0      0      4      0         0        0      16        7  2016
# 1      0      0      0         0        0       0        0  2016
# 2      1      7      0         0        3       5        9  2016
# 3      0      0      0         0        0       0        0  2016
# 4      0     12      2         0        1      21        9  2016

# %%
all_fires.to_csv('all_fires.csv')
